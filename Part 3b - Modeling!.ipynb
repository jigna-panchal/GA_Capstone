# %% [markdown]
# # Part 3 - Modeling!

# %% [markdown]
# ### Load CSV of Friends Transcript

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from tqdm import tqdm
import seaborn as sns

# %%
df = pd.read_csv('friends_transcripts_clean.csv')

# %%
df.drop(axis=1, columns=['Unnamed: 0', 'Line'], inplace=True)

# %%
df.head()
# Out:
#    Season  Episode                                              Title  \
# 0       1      101  The One Where Monica Gets a New Roomate (The P...
# 1       1      101  The One Where Monica Gets a New Roomate (The P...
# 2       1      101  The One Where Monica Gets a New Roomate (The P...
# 3       1      101  The One Where Monica Gets a New Roomate (The P...
# 4       1      101  The One Where Monica Gets a New Roomate (The P...
#
#   Character                                        Clean_Lines
# 0    Monica   There's nothing to tell! He's just some guy I...
# 1      Joey   C'mon, you're going out with the guy! There's...
# 2  Chandler   All right Joey, be nice.  So does he have a h...
# 3    Phoebe                           Wait, does he eat chalk?
# 4    Phoebe   Just, 'cause, I don't want her to go through ...

# %% [markdown]
# ## Modeling

# %% [markdown]
# We will be training multiple models on our dataset and picking the best performing one. We will look at the following three models: Logistic Regression, Naive Bayes, and Random Forest.
#
# We will train the models using a subset of data our called training set and validate with another subset called testing set.
#
# Our models will be trained using k-fold cross validation. Using this method we train our models multiple times using different set of training and test data. k-fold helps us to predict the performance of our models on unavailable data.

# %% [markdown]
# ### Using Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, confusion_matrix
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score

# %%
#Label Encode y
from sklearn.preprocessing import LabelEncoder

# %%
X = df.Clean_Lines
y = df.Character
# Setting training and testing data
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X, y, df.index, test_size=.2, random_state=1)

# %%
le = LabelEncoder()
le.fit(y_train)
y_train_le = le.transform(y_train)
y_test_le = le.transform(y_test)
y_le = le.transform(y)

# %%
sw = stopwords.words("english")
add_words = ["now","oh","know","yeah","hey","okay","right"]
stp_wrds = sw+add_words

# %%
# %%time
model = make_pipeline(CountVectorizer(stop_words='english',
                                      ngram_range=(1,3),
#                                       lowercase=True,
#                                       min_df=2
                                     ),
                      LogisticRegression(),
                      )
model.fit(X_train, y_train_le)
y_pred = model.predict(X_test)
print(accuracy_score(y_test_le, y_pred))
print("Number of features:", len(model.steps[0][1].get_feature_names()))
# Out:
# 0.2988494247123562
# Number of features: 219010
# Wall time: 42 s

# %%
import os
import pickle

with open("model.pkl","wb") as pkl_file:
    pickle.dump(model,pkl_file)

# %%
with open("model.pkl","rb") as pkl_file:
    model2 = pickle.load(pkl_file)

# %%
# %%time
model_name = model.__class__.__name__
number_of_folds = 5
entries = []

accuracies = cross_val_score(model, X, y_le, scoring='accuracy', cv=number_of_folds)
for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
        
cross_validations_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
display(cross_validations_df)
# Out:
#   model_name  fold_idx  accuracy
# 0   Pipeline         0  0.265906
# 1   Pipeline         1  0.274210
# 2   Pipeline         2  0.271709
# 3   Pipeline         3  0.268161
# 4   Pipeline         4  0.268342
# Wall time: 2min 51s

# %%
sns.boxplot(
    x='model_name',
    y='accuracy',
    data=cross_validations_df
);

# %% [markdown]
# We see that the Multinomial Naive Bayes model has a high variance. This means that the model was overfitting to the training data. Using cross validation helped us spot this shortcoming.
#
# We also see that LogisticRegression performed the best in this case. Naive Bayes and Random Forest Classifier are generally considered to be better models. But there is no such thing as a 'better model' and we have to try out various models to find out what works best for a given dataset.
#
# Now lets look at the accuracy of our models.

# %%
cross_validations_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# Pipeline    0.269665
# Name: accuracy, dtype: float64

# %% [markdown]
# The accuracy values are not the best but they are definitely better than flipping a coin. Accuracy for a coin flip is about 0.2 accuracy for 5 casts. We are getting better number from all our models with LogisticRegression performing the best at 0.5.
#
# We will do further analysis on our winning LogisticRegression model by generating a confusion matrix.

# %%
# visualizing confusion matrix
conf_mat = confusion_matrix(y_test_le, y_pred)
sns.heatmap(
    conf_mat,
    annot=True,
    fmt='d',    
    xticklabels=le.classes_,
    yticklabels=le.classes_
)
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5,15,'Predicted')

# %% [markdown]
# Because our model did not have high accuracy, we see that our predictions are all over the place. We see very high prediction number for Frasier because he has the most number of documents in the dataset.
#
# Lets pick some incorrect classifications and try to find what caused them.

# %%
id_to_cast = {cast_id:name for cast_id, name in zip (set(y_le), le.classes_)}

# %%
cast_to_id = {name:cast_id for name, cast_id in zip(le.classes_, set(y_le))}

# %%
for predicted in set(y_le):
    count = 0
    for actual in set(y_le):
        if predicted != actual and conf_mat[actual, predicted] >= 2:        
            print(
                "'{}' predicted as '{}'".format(
                    le.classes_[actual],
                    le.classes_[predicted],
                )
            )
            print("-" * 10)
            print("\n".join(df.loc[indices_test[(y_test_le == actual) & (y_pred == predicted)]].head().Clean_Lines.tolist()))
            print("\n")
# Out:
# 'Joey' predicted as 'Chandler'
# ----------
# What're you talking about, everybody loves Joseph.
#  Ill see you at 8:00.
#  Whos Elaine?
# Joseph's good, isn't he?
#  Uuuh.. yes, they are my stuffed clams.
#
#
# 'Monica' predicted as 'Chandler'
# ----------
#  Spend more time with the tie. That'll make a baby.
#  No its not, its second.
#  Yes!!
#  Yes.
#  Now everybody knows the basic erogenous zones.  You got one, two three, four s more than three), five, six, and seven!
#
#
# 'Phoebe' predicted as 'Chandler'
# ----------
#  Okay, you're on.
#  Yes. Definitely! Yes! Let's live in an apartment that we both live in! .)
#  What happened?
#  Fine! You go learn from your qualified instructor! But don't come crying to me when everyone's sick and tired of hearing you play Bad, Bad Leroy Brown!!
#  Okay. .)
#
#
# 'Rachel' predicted as 'Chandler'
# ----------
#  Okay. .)
#  Dont!! .)
# I can't believe this is happening.
#  Okay.
#  No! It didnt! Thats what I want to talk to you about.  Now, just to brief you  I may cry, but they are not tears of sadness or of anger, but just of me having this discussion with you.
#
#
# 'Ross' predicted as 'Chandler'
# ----------
#  Okay, well the ??? is not home.
#   But, you left!
#  Not all bad.
#  Oh myCome here! Come here! .) Its okay. Everythings gonna be okay.
#  You were the 200-pound 11-year-old who rode her!
#
#
# 'Chandler' predicted as 'Joey'
# ----------
#  What, like a number?
#  Well, it sounds kinda stupid...  Whos she?
#  It is starting to get dark out there.
#   All right! I found one that fits!
#  He had sex with Mr. Garibaldi!
#
#
# 'Monica' predicted as 'Joey'
# ----------
#  Yeah, Ginger something.
#  Huh, Chandler  youre home!
#  Hey!
#  We know how tough those parent/teacher conferences can be.
#  Hey! So what do you think?
#
#
# 'Phoebe' predicted as 'Joey'
# ----------
#  Yeah, Ive discovered that Ross forgot to take his brain medicine, uh, now without it, uh, in the brain of Ross, uh womens names are interchangeable, through-through no fault of his own.
#  What does that mean?   Does he sell it, drink it, or just complain a lot? 't know.)
#  Yeah!
#  Estelle? Why?
#  My Saturn dealership.
#
#
# 'Rachel' predicted as 'Joey'
# ----------
#   Hey!
#  Hey!
#  No, we kinda broke up instead.
#  Yeah.
#  Yeah
#
#
# 'Ross' predicted as 'Joey'
# ----------
#  He hasnt gotten out of that chair in two days.
#   Damnit!                              . Rachel just enters, sees                              him and starts laughing)
#  Wait, wait, wait.
#  Im sorry the answer there would be...none of us.
#  Give me the bag.
#
#
# 'Chandler' predicted as 'Monica'
# ----------
#
#  Well, I think you need to come out of your shell just a little.
#  Hey, relax I just need more time. Were going to dinner tonight.
#   Hey! Phoebe! We can talk to Phoebe!!
#   I love you.
#
#
# 'Joey' predicted as 'Monica'
# ----------
#  But plus, it would be wrong and weird and-and-and bad.
#  Chandler.
#  You said, you wanna come in for some lemonade?
#  LAURA! , very confident)
#  But the auditions in a couple hours and I dont even understand the game.
#
#
# 'Phoebe' predicted as 'Monica'
# ----------
# Oh God, here we go. For the first time in my life I'm gonna say 'Hi birthfather'.
#
#  Archery?
#  Um, were you planning on kissing me ever?
#  Wait-wait-wait-wait! So, explain something to me though, if, if nobody tagged Rachel, then isnt the play still going.
#
#
# 'Rachel' predicted as 'Monica'
# ----------
#  This one? .)
#  No!
#   Nothing?
#   What?
#  I dumped him.
#
#
# 'Ross' predicted as 'Monica'
# ----------
#  Sweetie, you gotta relax. Everythings gonna be great, okay? Come on. Come on.
#  About what?
#  There you go.
#  I didn't.
#  What?!
#
#
# 'Chandler' predicted as 'Phoebe'
# ----------
#  Yeah, he's better!
#  Ahh, ooh, try a hard 8.
#  She has a real name.
#  Listen, it's kind of an emergency. Well, I guess you know that, or we'd be in the predicament room. .)
#  Ohh, umm, y'know what, I already ate.
#
#
# 'Joey' predicted as 'Phoebe'
# ----------
#  Okay, good, so there you go. Go with Vince.
#  Oh, sometimes we use the same extras for different parts. It's
#  Oh hey, don't worry. I'm still ordained from                            your wedding.
#  Listen, sorry I didnt stop by last night but I had a date.
#  Ooh, that bad, huh?
#
#
# 'Monica' predicted as 'Phoebe'
# ----------
#  Oh, good.
#  Cause I dont want to encourage this kind of behaviour.
#  Uh-huh, what exactly did you ask her?
#  I cant find garbage bags!
#  Umm, wait! Do you want to set the mood a little?
#
#
# 'Rachel' predicted as 'Phoebe'
# ----------
#  Oh its important!
#  Oh, that doesn't mean anything.
#  Okay, its justand this is really embarrassingbut lately with this whole pregnancy thing Im just finding myselfhow do I put this umm, erotically charged.
#  Oooh.
#  So, if I wanna have my kid when Im 35, I dont have to get pregnant until Im 34. Which gives Prada four years to start making maternity clothes! Oh wait, but I do want to be married for a year before I get pregnant
#
#
# 'Ross' predicted as 'Phoebe'
# ----------
#  Uh-huh, that's why they call it Staten Island.
#  What, oh my God. What did you do?
#  Uh-huh.
#  How sad are we?
#  Hey, wait! Wait-wait-wait! Joey, did you propose to her?
#
#
# 'Chandler' predicted as 'Rachel'
# ----------
#  I wanted to be with you. I missed you so much.
#  Oh! It's on! It's on!
#  Whoever stood you up is a jerk.
#  Oh, it would be you! You! Monica! And you'd get all the votes!
#   Yknow, we havent found anybody else.
#
#
# 'Joey' predicted as 'Rachel'
# ----------
#   Uhm... oh! Okay. You come with me,                            and you tell them that the house is haunted!
#   Oh my God!!! I cant believe that!!
#  Good night!
#  I dont know.
#  Pheebs!
#
#
# 'Monica' predicted as 'Rachel'
# ----------
#  Whos Mr. Garibaldi?
#  Kinda like your barcalounger.
#  Oh my God!
#  Oh.
# Joey, promise me something.
#
#
# 'Phoebe' predicted as 'Rachel'
# ----------
#  No-No! You need your sleep. Night-night! Shh! .)
#  Wow, cute one!
#  Okay but thats why you have to buy it, so it can fulfil its Christmas destiny, otherwise there gonna throw it into the chipper. Tell him, Joey
#  Oh, wait, she's walking across the floor.. she's walking.. she's walking.. she's going for the pizza-  Hey, that's not for you, bitch! .)
#  Oh, youre such a gentleman. .) Come on! Were going to my place! .)
#
#
# 'Ross' predicted as 'Rachel'
# ----------
#  No-no, thank you Miranda.
#  So, so, now do I get Joey?
# Oh my God, what happened?
#  Oh, I'm so excited, I mean, apparently I beat                            out hundreds of other applicants, included five guys                            I went to graduate school with. Not that I'm keeping                            score or anything... five!
#  .) Oh God!
#
#
# 'Chandler' predicted as 'Ross'
# ----------
#  That new mountain bike?
#  So ah, Joey tells me you two met in acting class.
#  Marcel?
#  I need you to come to this bachelor party for my weird cousin Albert, y'know he's the botanist.
#  You sure you don't wanna stick around a little longer?
#
#
# 'Joey' predicted as 'Ross'
# ----------
#  So the ah, plays pretty great, huh?
#  Fine!
#  Come on, they're close.
#  Thats right! I helped you guys out a lot in the start of your relationship. Huh? I helped you guys sneak around for like six months, and I looked like an idiot! And I was humiliated. And I only made 200 dollars!
#  What the hell does a paleontologist need a beeper for?
#
#
# 'Monica' predicted as 'Ross'
# ----------
#   Yeah, we had a great time, thank   you!
#  Rach, try holding her a different way.
#  Sure.
#  Yeah, I think we're ready for our first course. , Monica brings over a tray) OK, um, these are rot-shrimp ravioli, and celantro pondou sauce... , quickly)... with just a touch of mints... and... ... ginger.
#  No, only because that's the graduation song.
#
#
# 'Phoebe' predicted as 'Ross'
# ----------
#  PHOE-BE!
#  That was a test and you just failed.
#  I cant believe that! Now the only thing left of my grandmothers legacy is this crumb. .) I wish you a long and happy marriage.
#  Okay, this will keep them away from your stuff. .)
#  Yeah, I had a date with this guy, and I swear to God, he is her other half.
#
#
# 'Rachel' predicted as 'Ross'
# ----------
#  Okay, okay, okay should I be scared?
#  Umm, our situation. Yknow umm, what we mean to each other. And I mean we-were having this baby together, and we live together. Isnt that, isnt that weird?
#  Whatyeahwhat, yknow what? I hope Emily is a lesbian.
#  You have a play date with a stripper?!
#  Thank you. .) Hey-hey umm, uh, is there, is there any such thing as an annulment shower?

# %% [markdown]
# To understand the incorrect prediction one has to know the characters of the data well(This is where a domain expert would come into play in real life data science problems.)
# #### Insert analysis on the character

# %%
number_of_words = 5
for cast, cast_id in sorted(cast_to_id.items()):
    indices = np.argsort(model.steps[1][1].coef_[cast_id])
    feature_names = np.array(model.steps[0][1].get_feature_names())[indices]
    unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:number_of_words]
    bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:number_of_words]
    print("# '{}':".format(cast))
    print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
    print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # 'Chandler':
#   . Top unigrams:
#        . joe
#        . eddie
#        . janice
#        . babe
#        . tulsa
#   . Top bigrams:
#        . oh come
#        . chandler bing
#        . big guy
#        . hello children
#        . oh yes
# # 'Joey':
#   . Top unigrams:
#        . comin
#        . dude
#        . agent
#        . doin
#        . kate
#   . Top bigrams:
#        . hi joey
#        . okay phoebe
#        . joey tribbiani
#        . pheebs sorry
#        . know yeah
# # 'Monica':
#   . Top unigrams:
#        . sweetie
#        . pete
#        . plates
#        . lasagnas
#        . nana
#   . Top bigrams:
#        . monica geller
#        . god emma
#        . did like
#        . hey good
#        . hell yeah
# # 'Phoebe':
#   . Top unigrams:
#        . frank
#        . mike
#        . yay
#        . ursula
#        . massage
#   . Top bigrams:
#        . uh huh
#        . uh hmm
#        . uh joe
#        . chandler monica
#        . oh guy
# # 'Rachel':
#   . Top unigrams:
#        . joshua
#        . barry
#        . ugh
#        . joanna
#        . tag
#   . Top bigrams:
#        . rachel green
#        . phoebe okay
#        . make stop
#        . umm gonna
#        . yeah sure
# # 'Ross':
#   . Top unigrams:
#        . carol
#        . emily
#        . ben
#        . correct
#        . susan
#   . Top bigrams:
#        . ross geller
#        . yes yes
#        . don don
#        . hey right
#        . okay okay

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(mode='RGBA',background_color='white',colormap='Spectral',random_state=2)

# %%
rachel_dialogue = str(0)
for line in df.Clean_Lines[df.Character=='Rachel']:
    rachel_dialogue+=line

# %%
wc.generate_from_text(rachel_dialogue)

# %%
#Make a Word Cloud for each Character
wc_gen = {}
wc = WordCloud(mode='RGBA',background_color='black',colormap='rainbow',random_state=2)

fig, ax = plt.subplots(nrows=6,figsize=(12,40))

for cast, cast_id in sorted(cast_to_id.items()):
    cast_dialogue = str(0)
    for line in df.Clean_Lines[df.Character == cast]:
        cast_dialogue+=line
    wc_gen[cast_id] = wc.generate_from_text(cast_dialogue)
    ax[cast_id].imshow(wc_gen[cast_id])
    ax[cast_id].set_title(cast,fontsize=24)
    ax[cast_id].set_xticks([])
    ax[cast_id].set_yticks([])
    
plt.show()

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# ### Once we have determined which classification model works best with our data, we can now set that as our model and use it to predict

# %%
# function printing document and assigned class
def my_classifier(my_list):
    my_pred = model.predict(my_list)
    preds = [le.classes_[pred] for pred in my_pred]
    return list(zip(my_list,preds))

# print function
def my_printer(my):
    for i in range(len(my)):
        print('Word/Phrase: ')
        print(my[i][0])
        print('Assigned Character: ')
        print(my[i][1])
        print()

# %%
# single words
my_list = ['men','women','tree','shark','computer','internet','star',
               'quantum','magnet','english','swimming','horse','rain']
my = my_classifier(my_list)

# %%
my_printer(my)
# Out:
# Word/Phrase:
# men
# Assigned Character:
# Rachel
#
# Word/Phrase:
# women
# Assigned Character:
# Joey
#
# Word/Phrase:
# tree
# Assigned Character:
# Phoebe
#
# Word/Phrase:
# shark
# Assigned Character:
# Monica
#
# Word/Phrase:
# computer
# Assigned Character:
# Chandler
#
# Word/Phrase:
# internet
# Assigned Character:
# Chandler
#
# Word/Phrase:
# star
# Assigned Character:
# Monica
#
# Word/Phrase:
# quantum
# Assigned Character:
# Monica
#
# Word/Phrase:
# magnet
# Assigned Character:
# Monica
#
# Word/Phrase:
# english
# Assigned Character:
# Ross
#
# Word/Phrase:
# swimming
# Assigned Character:
# Chandler
#
# Word/Phrase:
# horse
# Assigned Character:
# Monica
#
# Word/Phrase:
# rain
# Assigned Character:
# Ross

# %% [markdown]
# #### Try with a recognizable line from each character

# %%
# Joey - How you doin 
joey = ['How you doin?']
my = my_classifier(joey)
my_printer(my)
# Out:
# Word/Phrase:
# How you doin?
# Assigned Character:
# Joey

# %%
# Ross - We were on a break! 
ross = ['We were on a break!']
my = my_classifier(ross)
my_printer(my)
# Out:
# Word/Phrase:
# We were on a break!
# Assigned Character:
# Ross

# %%
# Rachel - How you doin 
rachel = ['Ralph lauren, bloomingdales, fashion']
my = my_classifier(rachel)
my_printer(my)
# Out:
# Word/Phrase:
# Ralph lauren, bloomingdales, fashion
# Assigned Character:
# Rachel

# %%
# Monica - How you doin 
monica = ['I love having things organized and clean']
my = my_classifier(monica)
my_printer(my)
# Out:
# Word/Phrase:
# I love having things organized and clean
# Assigned Character:
# Monica

# %%
# Chandler - How you doin 
chandler = ['My father was a headliner at a gay nightclub']
my = my_classifier(chandler)
my_printer(my)
# Out:
# Word/Phrase:
# My father was a headliner at a gay nightclub
# Assigned Character:
# Chandler

# %%
# Phoebe - My psychic told me I'm going to die 
phoebe = ['My psychic told me Im going to die']
my = my_classifier(phoebe)
my_printer(my)
# Out:
# Word/Phrase:
# My psychic told me Im going to die
# Assigned Character:
# Phoebe
